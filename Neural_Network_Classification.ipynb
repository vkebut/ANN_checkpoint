# %% [markdown]
# # Neural Network Classification on the Iris Dataset
#
# This notebook demonstrates how to build, train, and evaluate a neural network using Keras to classify species in the Iris dataset.

# %%
# 📦 Step 1: Import Required Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## Step 2: Load and Explore the Dataset

# %%
iris = load_iris()
X = iris.data
y = iris.target

print("Feature names:", iris.feature_names)
print("Target names:", iris.target_names)
print("Shape of X:", X.shape)
print("Shape of y:", y.shape)

# %% [markdown]
# ## Step 3: Preprocess the Data

# %%
# One-hot encode target labels
y_encoded = to_categorical(y)

# Normalize features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_encoded, test_size=0.2, random_state=42)

# %% [markdown]
# ## Step 4: Build the Neural Network

# %%
model = Sequential()
model.add(Dense(10, input_shape=(4,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(3, activation='softmax'))  # 3 output classes

# %% [markdown]
# ## ⚙️ Step 5: Compile the Model

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## Step 6: Train the Model

# %%
history = model.fit(X_train, y_train, 
                    epochs=50, 
                    batch_size=5, 
                    validation_split=0.2, 
                    verbose=1)

# %% [markdown]
# ## Step 7: Evaluate the Model

# %%
loss, accuracy = model.evaluate(X_test, y_test)
print(f"Test Accuracy: {accuracy:.4f}")

# %% [markdown]
# ## Step 8: Classification Report and Confusion Matrix

# %%
y_pred = model.predict(X_test)
y_pred_labels = np.argmax(y_pred, axis=1)
y_true_labels = np.argmax(y_test, axis=1)

print("Classification Report:\n", classification_report(y_true_labels, y_pred_labels))
print("Confusion Matrix:\n", confusion_matrix(y_true_labels, y_pred_labels))
